# %%
pip install openfoodfacts
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Collecting openfoodfacts
#   Downloading openfoodfacts-2.6.1-py3-none-any.whl (58 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.3/58.3 KB 2.6 MB/s eta 0:00:00
# Collecting pydantic<3.0.0,>=2.0.0
#   Downloading pydantic-2.11.6-py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.7/444.7 KB 10.8 MB/s eta 0:00:0000:01
# Collecting tqdm<5.0.0,>=4.0.0
#   Downloading tqdm-4.67.1-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 KB 9.0 MB/s eta 0:00:00
# Requirement already satisfied: requests>=2.20.0 in /usr/lib/python3/dist-packages (from openfoodfacts) (2.25.1)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (2.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 19.6 MB/s eta 0:00:00a 0:00:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting typing-extensions>=4.12.2
#   Downloading typing_extensions-4.14.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.8/43.8 KB 4.2 MB/s eta 0:00:00
# Installing collected packages: typing-extensions, tqdm, annotated-types, typing-inspection, pydantic-core, pydantic, openfoodfacts
# Successfully installed annotated-types-0.7.0 openfoodfacts-2.6.1 pydantic-2.11.6 pydantic-core-2.33.2 tqdm-4.67.1 typing-extensions-4.14.0 typing-inspection-0.4.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import openfoodfacts

# User-Agent is mandatory
api = openfoodfacts.API(user_agent="MyAwesomeApp/1.0")

# %%
api.product.text_search("Salmon")
# {"count": 3006628, "page": 1, "page_count": 20, "page_size": 20, "products": [{...}], "skip": 0}
# Out:
# {'count': 10704,
#  'page': 1,
#  'page_count': 20,
#  'page_size': 20,
#  'products': [{'_id': '5035272937469',
#    '_keywords': ['dishe',
#     'fish',
#     'meal',
#     'poke',
#     'rainbow',
#     'rice',
#     'salmon',
#     'sushi-and-maki',
#     'with',
#     'yo'],
#    'added_countries_tags': [],
#    'additives_n': 0,
#    'additives_original_tags': [],
#    'additives_tags': [],
#    'allergens': 'en:fish,en:soybeans',
#    'allergens_from_ingredients': 'en:gluten, en:soybeans, en:sesame-seeds, en:soybeans, en:gluten, en:soybeans, en:fish, en:fish, fish, soya, wheat, sesame seed, soya, wheat, salmon',
#    'allergens_from_user': '(en) en:fish,en:soybeans, en:fish, en:soybeans',
#    'allergens_hierarchy': ['en:fish',
#     'en:gluten',
#     'en:sesame-seeds',
#     'en:soybeans'],
#    'allergens_tags': ['en:fish',
#     'en:gluten',
#     'en:sesame-seeds',
#     'en:soybeans'],
#    'amino_acids_tags': [],
#    'brands': 'Yo!',
#    'brands_tags': ['yo'],
#    'categories': 'Meals, Meals with fish, Rice dishes, Meals with salmon, en:sushi-and-maki',
#    'categories_hierarchy': ['en:meals',
#     'en:meals-with-fish',
#     'en:rice-dishes',
#     'en:meals-with-salmon',
#     'en:sushi-and-maki'],
#    'categories_lc': 'en',
#    'categories_old': 'Rainbow-salmon-poke,Meals with salmon',
#    'categories_properties': {},
#    'categories_properties_tags': ['all-products',
#     'categories-known',
#     'agribalyse-food-code-unknown',
#     'agribalyse-proxy-food-code-unknown',
#     'ciqual-food-code-unknown',
#     'agribalyse-unknown'],
#    'categories_tags': ['en:meals',
#     'en:meals-with-fish',
#     'en:rice-dishes',
#     'en:meals-with-salmon',
#     'en:sushi-and-maki'],
#    'checkers_tags': [],
#    'code': '5035272937469',
#    'codes_tags': ['code-13',
#     '5035272937xxx',
#     '503527293xxxx',
#     '50352729xxxxx',
#     '5035272xxxxxx',
#     '503527xxxxxxx',
#     '50352xxxxxxxx',
#     '5035xxxxxxxxx',
#     '503xxxxxxxxxx',
#     '50xxxxxxxxxxx',
#     '5xxxxxxxxxxxx'],
#    'compared_to_category': 'en:sushi-and-maki',
#    'complete': 0,
#    'completeness': 0.8,
#    'correctors_tags': ['obondo',
#     'openfoodfacts-contributors',
#     'macrofactor',
#     'momonowaa',
#     'mathilde44'],
#    'countries': 'en:United Kingdom',
#    'countries_hierarchy': ['en:united-kingdom'],
#    'countries_tags': ['en:united-kingdom'],
#    'created_t': 1694953347,
#    'creator': 'smoothie-app',
#    'data_quality_bugs_tags': [],
#    'data_quality_errors_tags': [],
#    'data_quality_info_tags': ['en:packaging-data-incomplete',
#     'en:ingredients-percent-analysis-ok',
#     'en:environmental-score-extended-data-not-computed',
#     'en:food-groups-1-known',
#     'en:food-groups-2-known',
#     'en:food-groups-3-unknown'],
#    'data_quality_tags': ['en:packaging-data-incomplete',
#     'en:ingredients-percent-analysis-ok',
#     'en:environmental-score-extended-data-not-computed',
#     'en:food-groups-1-known',
#     'en:food-groups-2-known',
#     'en:food-groups-3-unknown',
#     'en:environmental-score-origins-of-ingredients-origins-are-100-percent-unknown',
#     'en:environmental-score-packaging-unspecified-material',
#     'en:environmental-score-production-system-no-label'],
#    'data_quality_warnings_tags': ['en:environmental-score-origins-of-ingredients-origins-are-100-percent-unknown',
#     'en:environmental-score-packaging-unspecified-material',
#     'en:environmental-score-production-system-no-label'],
#    'data_sources': 'App - smoothie-openfoodfacts, Apps, App - macrofactor',
#    'data_sources_tags': ['app-smoothie-openfoodfacts',
#     'apps',
#     'app-macrofactor'],
#    'ecoscore_data': {'adjustments': {'origins_of_ingredients': {'aggregated_origins': [{'epi_score': 0,
#         'origin': 'en:unknown',
#         'percent': 100,
#         'transportation_score': 0}],
#       'epi_score': 0,
#       'epi_value': -5,
#       'origins_from_categories': ['en:unknown'],
#       'origins_from_origins_field': ['en:unknown'],
#       'transportation_score': 0,
#       'transportation_scores': {'ad': 0,
#        'al': 0,
#        'at': 0,
#        'ax': 0,
#        'ba': 0,
#        'be': 0,
#        'bg': 0,
#        'ch': 0,
#        'cy': 0,
#        'cz': 0,
#        'de': 0,
#        'dk': 0,
#        'dz': 0,
#        'ee': 0,
#        'eg': 0,
#        'es': 0,
#        'fi': 0,
#        'fo': 0,
#        'fr': 0,
#        'gg': 0,
#        'gi': 0,
#        'gr': 0,
#        'hr': 0,
#        'hu': 0,
#        'ie': 0,
#        'il': 0,
#        'im': 0,
#        'is': 0,
#        'it': 0,
#        'je': 0,
#        'lb': 0,
#        'li': 0,
#        'lt': 0,
#        'lu': 0,
#        'lv': 0,
#        'ly': 0,
#        'ma': 0,
#        'mc': 0,
#        'md': 0,
#        'me': 0,
#        'mk': 0,
#        'mt': 0,
#        'nl': 0,
#        'no': 0,
#        'pl': 0,
#        'ps': 0,
#        'pt': 0,
#        'ro': 0,
#        'rs': 0,
#        'se': 0,
#        'si': 0,
#        'sj': 0,
#        'sk': 0,
#        'sm': 0,
#        'sy': 0,
#        'tn': 0,
#        'tr': 0,
#        'ua': 0,
#        'uk': 0,
#        'us': 0,
#        'va': 0,
#        'world': 0,
#        'xk': 0},
#       'transportation_value': 0,
#       'transportation_values': {'ad': 0,
#        'al': 0,
#        'at': 0,
#        'ax': 0,
#        'ba': 0,
#        'be': 0,
#        'bg': 0,
#        'ch': 0,
#        'cy': 0,
#        'cz': 0,
#        'de': 0,
#        'dk': 0,
#        'dz': 0,
#        'ee': 0,
#        'eg': 0,
#        'es': 0,
#        'fi': 0,
#        'fo': 0,
#        'fr': 0,
#        'gg': 0,
#        'gi': 0,
#        'gr': 0,
#        'hr': 0,
#        'hu': 0,
#        'ie': 0,
#        'il': 0,
#        'im': 0,
#        'is': 0,
#        'it': 0,
#        'je': 0,
#        'lb': 0,
#        'li': 0,
#        'lt': 0,
#        'lu': 0,
#        'lv': 0,
#        'ly': 0,
#        'ma': 0,
#        'mc': 0,
#        'md': 0,
#        'me': 0,
#        'mk': 0,
#        'mt': 0,
#        'nl': 0,
#        'no': 0,
#        'pl': 0,
#        'ps': 0,
#        'pt': 0,
#        'ro': 0,
#        'rs': 0,
#        'se': 0,
#        'si': 0,
#        'sj': 0,
#        'sk': 0,
#        'sm': 0,
#        'sy': 0,
#        'tn': 0,
#        'tr': 0,
#        'ua': 0,
#        'uk': 0,
#        'us': 0,
#        'va': 0,
#        'world': 0,
#        'xk': 0},
#       'value': -5,
#       'values': {'ad': -5,
#        'al': -5,
#        'at': -5,
#        'ax': -5,
#        'ba': -5,
#        'be': -5,
#        'bg': -5,
#        'ch': -5,
#        'cy': -5,
#        'cz': -5,
#        'de': -5,
#        'dk': -5,
#        'dz': -5,
#        'ee': -5,
#        'eg': -5,
#        'es': -5,
#        'fi': -5,
#        'fo': -5,
#        'fr': -5,
#        'gg': -5,
#        'gi': -5,
#        'gr': -5,
#        'hr': -5,
#        'hu': -5,
#        'ie': -5,
#        'il': -5,
#        'im': -5,
#        'is': -5,
#        'it': -5,
#        'je': -5,
#        'lb': -5,
#        'li': -5,
#        'lt': -5,
#        'lu': -5,
#        'lv': -5,
#        'ly': -5,
#        'ma': -5,
#        'mc': -5,
#        'md': -5,
#        'me': -5,
#        'mk': -5,
#        'mt': -5,
#        'nl': -5,
#        'no': -5,
#        'pl': -5,
#        'ps': -5,
#        'pt': -5,
#        'ro': -5,
#        'rs': -5,
#        'se': -5,
#        'si': -5,
#        'sj': -5,
#        'sk': -5,
#        'sm': -5,
#        'sy': -5,
#        'tn': -5,
#        'tr': -5,
#        'ua': -5,
#        'uk': -5,
#        'us': -5,
#        'va': -5,
#        'world': -5,
#        'xk': -5},
#       'warning': 'origins_are_100_percent_unknown'},
#      'packaging': {'non_recyclable_and_non_biodegradable_materials': 0,
#       'packagings': [{'environmental_score_material_score': 0,
#         'environmental_score_shape_ratio': 1,
#         'material': 'en:unknown',
#         'shape': 'en:pot'}],
#       'score': 0,
#       'value': -10,
#       'warning': 'unspecified_material'},
#      'production_system': {'labels': [], 'value': 0, 'warning': 'no_label'},
#      'threatened_species': {'ingredient': 'en:palm-oil', 'value': -10}},
#     'agribalyse': {'warning': 'missing_agribalyse_match'},
#     'grade': 'unknown',
#     'missing': {'agb_category': 1, 'labels': 1, 'origins': 1, 'packagings': 1},
#     'missing_agribalyse_match_warning': 1,
#     'scores': {},
#     'status': 'unknown'},
#    'ecoscore_grade': 'unknown',
#    'ecoscore_tags': ['unknown'],
#    'editors_tags': ['foodvisor',
#     'macrofactor',
#     'mathilde44',
#     'momonowaa',
#     'obondo',
#     'openfoodfacts-contributors',
#     'rachipetal',
#     'roboto-app',
#     'smoothie-app'],
#    'entry_dates_tags': ['2023-09-17', '2023-09', '2023'],
#    'food_groups': 'en:one-dish-meals',
#    'food_groups_tags': ['en:composite-foods', 'en:one-dish-meals'],
#    'id': '5035272937469',
#    'image_front_small_url': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.200.jpg',
#    'image_front_thumb_url': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.100.jpg',
#    'image_front_url': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.400.jpg',
#    'image_small_url': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.200.jpg',
#    'image_thumb_url': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.100.jpg',
#    'image_url': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.400.jpg',
#    'images': {},
#    'informers_tags': ['smoothie-app',
#     'rachipetal',
#     'roboto-app',
#     'obondo',
#     'openfoodfacts-contributors',
#     'momonowaa'],
#    'ingredients': [{'ciqual_proxy_food_code': '9100',
#      'has_sub_ingredients': 'yes',
#      'id': 'en:cooked-rice',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 46.75,
#      'percent_max': 59,
#      'percent_min': 34.5,
#      'rank': 1,
#      'text': 'Cooked rice',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '26036',
#      'has_sub_ingredients': 'yes',
#      'id': 'en:salmon',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 22.25,
#      'percent_max': 34.5,
#      'percent_min': 10,
#      'rank': 2,
#      'text': 'salmon',
#      'vegan': 'no',
#      'vegetarian': 'no'},
#     {'has_sub_ingredients': 'yes',
#      'id': 'en:soy-sesame-dressing',
#      'is_in_taxonomy': 0,
#      'percent': 10,
#      'percent_estimate': 10,
#      'percent_max': 10,
#      'percent_min': 10,
#      'rank': 3,
#      'text': 'soy sesame dressing'},
#     {'ciqual_food_code': '20901',
#      'id': 'en:edamame',
#      'is_in_taxonomy': 1,
#      'percent': 8,
#      'percent_estimate': 8,
#      'percent_max': 8,
#      'percent_min': 8,
#      'rank': 4,
#      'text': 'edamame beans',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '20014',
#      'ecobalyse_code': 'red-cabbage-non-eu',
#      'has_sub_ingredients': 'yes',
#      'id': 'en:red-cabbage',
#      'is_in_taxonomy': 1,
#      'percent': 5,
#      'percent_estimate': 5,
#      'percent_max': 5,
#      'percent_min': 5,
#      'processing': 'en:pickled',
#      'rank': 5,
#      'text': 'red cabbage',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '20168',
#      'ecobalyse_code': 'bellpepper-unheated-greehouse',
#      'id': 'en:yellow-bell-pepper',
#      'is_in_taxonomy': 1,
#      'percent': 5,
#      'percent_estimate': 5,
#      'percent_max': 5,
#      'percent_min': 5,
#      'processing': 'en:grilled',
#      'rank': 6,
#      'text': 'yellow pepper',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'has_sub_ingredients': 'yes',
#      'id': 'en:crispy-onions',
#      'is_in_taxonomy': 0,
#      'percent': 3,
#      'percent_estimate': 3,
#      'percent_max': 3,
#      'percent_min': 3,
#      'rank': 7,
#      'text': 'crispy onions'},
#     {'ciqual_food_code': '18066',
#      'ecobalyse_code': 'tap-water',
#      'id': 'en:water',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 25.2916666666667,
#      'percent_max': 59,
#      'percent_min': 3.83333333333333,
#      'text': 'water',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_proxy_food_code': '9100',
#      'id': 'en:rice',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 10.7291666666667,
#      'percent_max': 29.5,
#      'percent_min': 0,
#      'text': 'rice',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_proxy_food_code': '31016',
#      'ecobalyse_code': 'sugar',
#      'id': 'en:sugar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 2.7,
#      'percent_max': 5.4,
#      'percent_min': 0,
#      'text': 'sugar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11018',
#      'id': 'en:spirit-vinegar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 2.7,
#      'percent_max': 5.4,
#      'percent_min': 0,
#      'text': 'spirit vinegar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11018',
#      'id': 'en:rice-vinegar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 2.66458333333333,
#      'percent_max': 5.4,
#      'percent_min': 0,
#      'text': 'rice vinegar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11058',
#      'id': 'en:salt',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.4375,
#      'percent_max': 0.875,
#      'percent_min': 0,
#      'text': 'salt',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '17130',
#      'ecobalyse_code': 'rapeseed-oil',
#      'from_palm_oil': 'no',
#      'id': 'en:rapeseed-oil',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.4375,
#      'percent_max': 0.875,
#      'percent_min': 0,
#      'text': 'rapeseed oil',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '31077',
#      'id': 'en:glucose-fructose-syrup',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.4375,
#      'percent_max': 0.875,
#      'percent_min': 0,
#      'text': 'fructose-glucose syrup',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '31067',
#      'ecobalyse_code': 'sugar',
#      'id': 'en:cane-sugar-molasses',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 1.35208333333333,
#      'percent_max': 0.875,
#      'percent_min': 0,
#      'text': 'cane molasses',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '26036',
#      'id': 'en:atlantic-salmon',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 22.25,
#      'percent_max': 34.5,
#      'percent_min': 10,
#      'text': 'Salmo salar',
#      'vegan': 'no',
#      'vegetarian': 'no'},
#     {'ciqual_food_code': '18066',
#      'ecobalyse_code': 'tap-water',
#      'id': 'en:water',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 5.35714285714286,
#      'percent_max': 10,
#      'percent_min': 0.714285714285714,
#      'text': 'water',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11104',
#      'has_sub_ingredients': 'yes',
#      'id': 'en:soy-sauce',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 2.32142857142857,
#      'percent_max': 5,
#      'percent_min': 0,
#      'text': 'soy sauce',
#      'vegan': 'maybe',
#      'vegetarian': 'maybe'},
#     {'ciqual_proxy_food_code': '31016',
#      'ecobalyse_code': 'sugar',
#      'id': 'en:sugar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 1.16071428571429,
#      'percent_max': 3.33333333333333,
#      'percent_min': 0,
#      'text': 'sugar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11018',
#      'id': 'en:rice-vinegar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.580357142857142,
#      'percent_max': 2.5,
#      'percent_min': 0,
#      'text': 'rice vinegar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '17400',
#      'from_palm_oil': 'no',
#      'id': 'en:sesame-oil',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.290178571428571,
#      'percent_max': 2,
#      'percent_min': 0,
#      'text': '_sesame seed_ oil',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '9510',
#      'id': 'en:modified-corn-starch',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.145089285714286,
#      'percent_max': 1.66666666666667,
#      'percent_min': 0,
#      'text': 'modified maize starch',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '20034',
#      'ecobalyse_code': 'onion-non-eu',
#      'id': 'en:onion',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.0725446428571423,
#      'percent_max': 1.42857142857143,
#      'percent_min': 0,
#      'processing': 'en:pureed',
#      'text': 'onion',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11018',
#      'id': 'en:spirit-vinegar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.0362723214285712,
#      'percent_max': 1.25,
#      'percent_min': 0,
#      'text': 'spirit vinegar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '2074',
#      'ecobalyse_code': 'apple-fr',
#      'id': 'en:apple-juice',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.0181361607142856,
#      'percent_max': 1.11111111111111,
#      'percent_min': 0,
#      'processing': 'en:concentrated',
#      'text': 'apple juice',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11074',
#      'id': 'en:ginger',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.00906808035714235,
#      'percent_max': 1,
#      'percent_min': 0,
#      'processing': 'en:pureed',
#      'text': 'ginger',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '2028',
#      'id': 'en:concentrated-lemon-juice',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.00453404017857117,
#      'percent_max': 0.909090909090909,
#      'percent_min': 0,
#      'text': 'lemon juice concentrate',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '13067',
#      'id': 'en:lime-juice-concentrate',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.00226702008928559,
#      'percent_max': 0.909090909090909,
#      'percent_min': 0,
#      'text': 'lime juice concentrate',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11000',
#      'id': 'en:garlic',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.00113351004464235,
#      'percent_max': 0.769230769230769,
#      'percent_min': 0,
#      'processing': 'en:powder',
#      'text': 'garlic',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11019',
#      'id': 'en:white-pepper',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.00113351004464235,
#      'percent_max': 0.769230769230769,
#      'percent_min': 0,
#      'text': 'white pepper',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '20014',
#      'ecobalyse_code': 'red-cabbage-non-eu',
#      'id': 'en:red-cabbage',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 3.125,
#      'percent_max': 5,
#      'percent_min': 1.25,
#      'text': 'red cabbage',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11018',
#      'id': 'en:rice-vinegar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.9375,
#      'percent_max': 2.5,
#      'percent_min': 0,
#      'text': 'rice vinegar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_proxy_food_code': '31016',
#      'ecobalyse_code': 'sugar',
#      'id': 'en:sugar',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.46875,
#      'percent_max': 1.66666666666667,
#      'percent_min': 0,
#      'text': 'sugar',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11058',
#      'id': 'en:salt',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.46875,
#      'percent_max': 0.875,
#      'percent_min': 0,
#      'text': 'salt',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '20034',
#      'ecobalyse_code': 'onion-non-eu',
#      'id': 'en:onion',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 1.875,
#      'percent_max': 3,
#      'percent_min': 0.75,
#      'text': 'onion',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '16129',
#      'ecobalyse_code': 'refined-palm-oil',
#      'from_palm_oil': 'yes',
#      'id': 'en:palm-oil',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.5625,
#      'percent_max': 1.5,
#      'percent_min': 0,
#      'text': 'palm oil',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_proxy_food_code': '9410',
#      'ecobalyse_code': 'flour',
#      'id': 'en:wheat-flour',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.28125,
#      'percent_max': 1,
#      'percent_min': 0,
#      'text': '_wheat_ flour',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11058',
#      'id': 'en:salt',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.28125,
#      'percent_max': 0.75,
#      'percent_min': 0,
#      'text': 'salt',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '18066',
#      'ecobalyse_code': 'tap-water',
#      'id': 'en:water',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 1.16071428571429,
#      'percent_max': 5,
#      'percent_min': 0,
#      'text': 'water',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '20901',
#      'id': 'en:soya-bean',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.580357142857143,
#      'percent_max': 2.5,
#      'percent_min': 0,
#      'text': '_soya_ beans',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_proxy_food_code': '9410',
#      'id': 'en:wheat',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.290178571428571,
#      'percent_max': 1.66666666666667,
#      'percent_min': 0,
#      'text': '_wheat_',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '11058',
#      'id': 'en:salt',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.145089285714286,
#      'percent_max': 0.875,
#      'percent_min': 0,
#      'text': 'salt',
#      'vegan': 'yes',
#      'vegetarian': 'yes'},
#     {'ciqual_food_code': '1014',
#      'id': 'en:alcohol',
#      'is_in_taxonomy': 1,
#      'percent_estimate': 0.145089285714286,
#      'percent_max': 0.875,
#      'percent_min': 0,
#      'text': 'alcohol',
#      'vegan': 'maybe',
#      'vegetarian': 'yes'}],
#    'ingredients_analysis': {'en:non-vegan': ['en:salmon',
#      'en:atlantic-salmon'],
#     'en:non-vegetarian': ['en:salmon', 'en:atlantic-salmon'],
#     'en:palm-oil': ['en:palm-oil'],
#     'en:vegan-status-unknown': ['en:soy-sesame-dressing', 'en:crispy-onions'],
#     'en:vegetarian-status-unknown': ['en:soy-sesame-dressing',
#      'en:crispy-onions']},
#    'ingredients_analysis_tags': ['en:palm-oil',
#     'en:non-vegan',
#     'en:non-vegetarian'],
#    'ingredients_from_or_that_may_be_from_palm_oil_n': 0,
#    'ingredients_from_palm_oil_n': 0,
#    'ingredients_from_palm_oil_tags': [],
#    'ingredients_hierarchy': ['en:cooked-rice',
#     'en:rice',
#     'en:salmon',
#     'en:fish',
#     'en:oily-fish',
#     'en:soy-sesame-dressing',
#     'en:edamame',
#     'en:vegetable',
#     'en:legume',
#     'en:pulse',
#     'en:soya',
#     'en:soya-bean',
#     'en:red-cabbage',
#     'en:brassica',
#     'en:cabbage',
#     'en:yellow-bell-pepper',
#     'en:fruit-vegetable',
#     'en:bell-pepper',
#     'en:crispy-onions',
#     'en:water',
#     'en:sugar',
#     'en:added-sugar',
#     'en:disaccharide',
#     'en:spirit-vinegar',
#     'en:vinegar',
#     'en:rice-vinegar',
#     'en:salt',
#     'en:rapeseed-oil',
#     'en:oil-and-fat',
#     'en:vegetable-oil-and-fat',
#     'en:glucose-fructose-syrup',
#     'en:monosaccharide',
#     'en:fructose',
#     'en:glucose',
#     'en:cane-sugar-molasses',
#     'en:molasses',
#     'en:atlantic-salmon',
#     'en:soy-sauce',
#     'en:sauce',
#     'en:sesame-oil',
#     'en:vegetable-oil',
#     'en:modified-corn-starch',
#     'en:starch',
#     'en:corn-starch',
#     'en:modified-starch',
#     'en:onion',
#     'en:root-vegetable',
#     'en:onion-family-vegetable',
#     'en:apple-juice',
#     'en:fruit',
#     'en:juice',
#     'en:malaceous-fruit',
#     'en:apple',
#     'en:fruit-juice',
#     'en:ginger',
#     'en:condiment',
#     'en:spice',
#     'en:concentrated-lemon-juice',
#     'en:lemon-juice',
#     'en:lime-juice-concentrate',
#     'en:citrus-fruit',
#     'en:lime',
#     'en:lime-juice',
#     'en:garlic',
#     'en:white-pepper',
#     'en:seed',
#     'en:pepper',
#     'en:palm-oil',
#     'en:palm-oil-and-fat',
#     'en:wheat-flour',
#     'en:cereal',
#     'en:flour',
#     'en:wheat',
#     'en:cereal-flour',
#     'en:alcohol'],
#    'ingredients_lc': 'en',
#    'ingredients_n': 44,
#    'ingredients_n_tags': ['44', '41-50'],
#    'ingredients_non_nutritive_sweeteners_n': 0,
#    'ingredients_original_tags': ['en:cooked-rice',
#     'en:salmon',
#     'en:soy-sesame-dressing',
#     'en:edamame',
#     'en:red-cabbage',
#     'en:yellow-bell-pepper',
#     'en:crispy-onions',
#     'en:water',
#     'en:rice',
#     'en:sugar',
#     'en:spirit-vinegar',
#     'en:rice-vinegar',
#     'en:salt',
#     'en:rapeseed-oil',
#     'en:glucose-fructose-syrup',
#     'en:cane-sugar-molasses',
#     'en:atlantic-salmon',
#     'en:water',
#     'en:soy-sauce',
#     'en:sugar',
#     'en:rice-vinegar',
#     'en:sesame-oil',
#     'en:modified-corn-starch',
#     'en:onion',
#     'en:spirit-vinegar',
#     'en:apple-juice',
#     'en:ginger',
#     'en:concentrated-lemon-juice',
#     'en:lime-juice-concentrate',
#     'en:garlic',
#     'en:white-pepper',
#     'en:red-cabbage',
#     'en:rice-vinegar',
#     'en:sugar',
#     'en:salt',
#     'en:onion',
#     'en:palm-oil',
#     'en:wheat-flour',
#     'en:salt',
#     'en:water',
#     'en:soya-bean',
#     'en:wheat',
#     'en:salt',
#     'en:alcohol'],
#    'ingredients_percent_analysis': 1,
#    'ingredients_sweeteners_n': 0,
#    'ingredients_tags': ['en:cooked-rice',
#     'en:rice',
#     'en:salmon',
#     'en:fish',
#     'en:oily-fish',
#     'en:soy-sesame-dressing',
#     'en:edamame',
#     'en:vegetable',
#     'en:legume',
#     'en:pulse',
#     'en:soya',
#     'en:soya-bean',
#     'en:red-cabbage',
#     'en:brassica',
#     'en:cabbage',
#     'en:yellow-bell-pepper',
#     'en:fruit-vegetable',
#     'en:bell-pepper',
#     'en:crispy-onions',
#     'en:water',
#     'en:sugar',
#     'en:added-sugar',
#     'en:disaccharide',
#     'en:spirit-vinegar',
#     'en:vinegar',
#     'en:rice-vinegar',
#     'en:salt',
#     'en:rapeseed-oil',
#     'en:oil-and-fat',
#     'en:vegetable-oil-and-fat',
#     'en:glucose-fructose-syrup',
#     'en:monosaccharide',
#     'en:fructose',
#     'en:glucose',
#     'en:cane-sugar-molasses',
#     'en:molasses',
#     'en:atlantic-salmon',
#     'en:soy-sauce',
#     'en:sauce',
#     'en:sesame-oil',
#     'en:vegetable-oil',
#     'en:modified-corn-starch',
#     'en:starch',
#     'en:corn-starch',
#     'en:modified-starch',
#     'en:onion',
#     'en:root-vegetable',
#     'en:onion-family-vegetable',
#     'en:apple-juice',
#     'en:fruit',
#     'en:juice',
#     'en:malaceous-fruit',
#     'en:apple',
#     'en:fruit-juice',
#     'en:ginger',
#     'en:condiment',
#     'en:spice',
#     'en:concentrated-lemon-juice',
#     'en:lemon-juice',
#     'en:lime-juice-concentrate',
#     'en:citrus-fruit',
#     'en:lime',
#     'en:lime-juice',
#     'en:garlic',
#     'en:white-pepper',
#     'en:seed',
#     'en:pepper',
#     'en:palm-oil',
#     'en:palm-oil-and-fat',
#     'en:wheat-flour',
#     'en:cereal',
#     'en:flour',
#     'en:wheat',
#     'en:cereal-flour',
#     'en:alcohol'],
#    'ingredients_text': 'Cooked rice (water, rice, sugar, spirit vinegar, rice vinegar, salt, rapeseed oil, fructose-glucose syrup, cane molasses), salmon (Salmo salar) (_fish_) (10%), soy sesame dressing (10%) (water, soy sauce (water, _soya_ beans, _wheat_, salt, alcohol), sugar, rice vinegar, _sesame seed_ oil, modified maize starch, onion purée, spirit vinegar, apple juice concentrate, ginger purée, lemon juice concentrate, lime juice concentrate, garlic powder, white pepper), edamame beans (8%) (_soya_), pickled red cabbage (5%) (red cabbage, rice vinegar, sugar, salt), grilled yellow pepper (5%), crispy onions (3%) (onion, palm oil, _wheat_ flour, salt).',
#    'ingredients_text_en': 'Cooked rice (water, rice, sugar, spirit vinegar, rice vinegar, salt, rapeseed oil, fructose-glucose syrup, cane molasses), salmon (Salmo salar) (_fish_) (10%), soy sesame dressing (10%) (water, soy sauce (water, _soya_ beans, _wheat_, salt, alcohol), sugar, rice vinegar, _sesame seed_ oil, modified maize starch, onion purée, spirit vinegar, apple juice concentrate, ginger purée, lemon juice concentrate, lime juice concentrate, garlic powder, white pepper), edamame beans (8%) (_soya_), pickled red cabbage (5%) (red cabbage, rice vinegar, sugar, salt), grilled yellow pepper (5%), crispy onions (3%) (onion, palm oil, _wheat_ flour, salt).',
#    'ingredients_text_with_allergens': 'Cooked rice (water, rice, sugar, spirit vinegar, rice vinegar, salt, rapeseed oil, fructose-glucose syrup, cane molasses), <span class="allergen">salmon</span> (Salmo salar) (<span class="allergen">fish</span>) (10%), soy sesame dressing (10%) (water, soy sauce (water, <span class="allergen">soya</span> beans, <span class="allergen">wheat</span>, salt, alcohol), sugar, rice vinegar, <span class="allergen">sesame seed</span> oil, modified maize starch, onion purée, spirit vinegar, apple juice concentrate, ginger purée, lemon juice concentrate, lime juice concentrate, garlic powder, white pepper), edamame beans (8%) (<span class="allergen">soya</span>), pickled red cabbage (5%) (red cabbage, rice vinegar, sugar, salt), grilled yellow pepper (5%), crispy onions (3%) (onion, palm oil, <span class="allergen">wheat</span> flour, salt).',
#    'ingredients_text_with_allergens_en': 'Cooked rice (water, rice, sugar, spirit vinegar, rice vinegar, salt, rapeseed oil, fructose-glucose syrup, cane molasses), <span class="allergen">salmon</span> (Salmo salar) (<span class="allergen">fish</span>) (10%), soy sesame dressing (10%) (water, soy sauce (water, <span class="allergen">soya</span> beans, <span class="allergen">wheat</span>, salt, alcohol), sugar, rice vinegar, <span class="allergen">sesame seed</span> oil, modified maize starch, onion purée, spirit vinegar, apple juice concentrate, ginger purée, lemon juice concentrate, lime juice concentrate, garlic powder, white pepper), edamame beans (8%) (<span class="allergen">soya</span>), pickled red cabbage (5%) (red cabbage, rice vinegar, sugar, salt), grilled yellow pepper (5%), crispy onions (3%) (onion, palm oil, <span class="allergen">wheat</span> flour, salt).',
#    'ingredients_that_may_be_from_palm_oil_n': 0,
#    'ingredients_that_may_be_from_palm_oil_tags': [],
#    'ingredients_with_specified_percent_n': 2,
#    'ingredients_with_specified_percent_sum': 13,
#    'ingredients_with_unspecified_percent_n': 36,
#    'ingredients_with_unspecified_percent_sum': 87,
#    'ingredients_without_ciqual_codes': ['en:crispy-onions',
#     'en:soy-sesame-dressing'],
#    'ingredients_without_ciqual_codes_n': 2,
#    'ingredients_without_ecobalyse_ids': ['en:alcohol',
#     'en:atlantic-salmon',
#     'en:concentrated-lemon-juice',
#     'en:cooked-rice',
#     'en:crispy-onions',
#     'en:edamame',
#     'en:garlic',
#     'en:ginger',
#     'en:glucose-fructose-syrup',
#     'en:lime-juice-concentrate',
#     'en:modified-corn-starch',
#     'en:rice',
#     'en:rice-vinegar',
#     'en:salmon',
#     'en:salt',
#     'en:sesame-oil',
#     'en:soy-sauce',
#     'en:soy-sesame-dressing',
#     'en:soya-bean',
#     'en:spirit-vinegar',
#     'en:wheat',
#     'en:white-pepper'],
#    'ingredients_without_ecobalyse_ids_n': 22,
#    'interface_version_created': '20120622',
#    'interface_version_modified': '20150316.jqm2',
#    'known_ingredients_n': 73,
#    'lang': 'en',
#    'languages': {'en:english': 5},
#    'languages_codes': {'en': 5},
#    'languages_hierarchy': ['en:english'],
#    'languages_tags': ['en:english', 'en:1'],
#    'last_edit_dates_tags': ['2025-02-18', '2025-02', '2025'],
#    'last_editor': 'foodvisor',
#    'last_image_dates_tags': ['2025-02-18', '2025-02', '2025'],
#    'last_image_t': 1739888316,
#    'last_modified_by': 'foodvisor',
#    'last_modified_t': 1739888316,
#    'last_updated_t': 1739888316,
#    'lc': 'en',
#    'main_countries_tags': [],
#    'max_imgid': 7,
#    'minerals_tags': [],
#    'misc_tags': ['en:at-least-5-ingredients-with-specified-percent',
#     'en:environmental-score-not-computed',
#     'en:nutriscore-2021-b-2023-c',
#     'en:nutriscore-2021-better-than-2023',
#     'en:nutriscore-2021-different-from-2023',
#     'en:nutriscore-computed',
#     'en:nutrition-all-nutriscore-values-known',
#     'en:nutrition-fruits-vegetables-legumes-estimate-from-ingredients',
#     'en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#     'en:packagings-not-complete',
#     'en:packagings-not-empty',
#     'en:packagings-not-empty-but-not-complete',
#     'en:packagings-number-of-components-1',
#     'en:some-ingredients-with-specified-percent',
#     'en:main-countries-uk-unexpectedly-low-scans',
#     'en:main-countries-uk-unexpectedly-low-scans-0-10-percent-of-expected',
#     'en:main-countries-old-product-without-scans-in-2020'],
#    'no_nutrition_data': '',
#    'nova_group': 4,
#    'nova_group_debug': '',
#    'nova_groups': '4',
#    'nova_groups_markers': {'3': [['categories', 'en:meals'],
#      ['ingredients', 'en:salt'],
#      ['ingredients', 'en:starch'],
#      ['ingredients', 'en:sugar'],
#      ['ingredients', 'en:vegetable-oil'],
#      ['ingredients', 'en:sauce']],
#     '4': [['ingredients', 'en:glucose'],
#      ['ingredients', 'en:fructose'],
#      ['ingredients', 'en:modified-starch']]},
#    'nova_groups_tags': ['en:4-ultra-processed-food-and-drink-products'],
#    'nucleotides_tags': [],
#    'nutrient_levels': {'fat': 'moderate',
#     'salt': 'moderate',
#     'saturated-fat': 'low',
#     'sugars': 'moderate'},
#    'nutrient_levels_tags': ['en:fat-in-moderate-quantity',
#     'en:saturated-fat-in-low-quantity',
#     'en:sugars-in-moderate-quantity',
#     'en:salt-in-moderate-quantity'],
#    'nutriments': {'carbohydrates': 25,
#     'carbohydrates_100g': 25,
#     'carbohydrates_serving': 70.8,
#     'carbohydrates_unit': 'g',
#     'carbohydrates_value': 25,
#     'energy': 661,
#     'energy-kcal': 158,
#     'energy-kcal_100g': 158,
#     'energy-kcal_serving': 447,
#     'energy-kcal_unit': 'kcal',
#     'energy-kcal_value': 158,
#     'energy-kcal_value_computed': 159.9,
#     'energy-kj': 661,
#     'energy-kj_100g': 661,
#     'energy-kj_serving': 1870,
#     'energy-kj_unit': 'kJ',
#     'energy-kj_value': 661,
#     'energy-kj_value_computed': 674.1,
#     'energy_100g': 661,
#     'energy_serving': 1870,
#     'energy_unit': 'kJ',
#     'energy_value': 661,
#     'fat': 4.1,
#     'fat_100g': 4.1,
#     'fat_serving': 11.6,
#     'fat_unit': 'g',
#     'fat_value': 4.1,
#     'fiber': 0.7,
#     'fiber_100g': 0.7,
#     'fiber_serving': 1.98,
#     'fiber_unit': 'g',
#     'fiber_value': 0.7,
#     'fruits-vegetables-legumes-estimate-from-ingredients_100g': 20.5528390066964,
#     'fruits-vegetables-legumes-estimate-from-ingredients_serving': 20.5528390066964,
#     'fruits-vegetables-nuts-estimate-from-ingredients_100g': 20.9903390066964,
#     'fruits-vegetables-nuts-estimate-from-ingredients_serving': 20.9903390066964,
#     'nova-group': 4,
#     'nova-group_100g': 4,
#     'nova-group_serving': 4,
#     'nutrition-score-fr': 4,
#     'nutrition-score-fr_100g': 4,
#     'proteins': 5.4,
#     'proteins_100g': 5.4,
#     'proteins_serving': 15.3,
#     'proteins_unit': 'g',
#     'proteins_value': 5.4,
#     'salt': 0.875,
#     'salt_100g': 0.875,
#     'salt_serving': 2.48,
#     'salt_unit': 'g',
#     'salt_value': 0.875,
#     'saturated-fat': 1,
#     'saturated-fat_100g': 1,
#     'saturated-fat_serving': 2.83,
#     'saturated-fat_unit': 'g',
#     'saturated-fat_value': 1,
#     'sodium': 0.35,
#     'sodium_100g': 0.35,
#     'sodium_serving': 0.99,
#     'sodium_unit': 'g',
#     'sodium_value': 0.35,
#     'sugars': 5.4,
#     'sugars_100g': 5.4,
#     'sugars_serving': 15.3,
#     'sugars_unit': 'g',
#     'sugars_value': 5.4},
#    'nutriscore': {'2021': {'category_available': 1,
#      'data': {'energy': 661,
#       'energy_points': 1,
#       'energy_value': 661,
#       'fiber': 0.7,
#       'fiber_points': 0,
#       'fiber_value': 0.7,
#       'fruits_vegetables_nuts_colza_walnut_olive_oils': 20.9903390066964,
#       'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#       'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 21,
#       'is_beverage': 0,
#       'is_cheese': 0,
#       'is_fat': 0,
#       'is_water': 0,
#       'negative_points': 5,
#       'positive_points': 3,
#       'proteins': 5.4,
#       'proteins_points': 3,
#       'proteins_value': 5.4,
#       'saturated_fat': 1,
#       'saturated_fat_points': 0,
#       'saturated_fat_value': 1,
#       'sodium': 350,
#       'sodium_points': 3,
#       'sodium_value': 350,
#       'sugars': 5.4,
#       'sugars_points': 1,
#       'sugars_value': 5.4},
#      'grade': 'b',
#      'nutrients_available': 1,
#      'nutriscore_applicable': 1,
#      'nutriscore_computed': 1,
#      'score': 2},
#     '2023': {'category_available': 1,
#      'data': {'components': {'negative': [{'id': 'energy',
#          'points': 1,
#          'points_max': 10,
#          'unit': 'kJ',
#          'value': 661},
#         {'id': 'sugars',
#          'points': 1,
#          'points_max': 15,
#          'unit': 'g',
#          'value': 5.4},
#         {'id': 'saturated_fat',
#          'points': 0,
#          'points_max': 10,
#          'unit': 'g',
#          'value': 1},
#         {'id': 'salt',
#          'points': 4,
#          'points_max': 20,
#          'unit': 'g',
#          'value': 0.88}],
#        'positive': [{'id': 'proteins',
#          'points': 2,
#          'points_max': 7,
#          'unit': 'g',
#          'value': 5.4},
#         {'id': 'fiber',
#          'points': 0,
#          'points_max': 5,
#          'unit': 'g',
#          'value': 0.7},
#         {'id': 'fruits_vegetables_legumes',
#          'points': 0,
#          'points_max': 5,
#          'unit': '%',
#          'value': 20.6}]},
#       'count_proteins': 1,
#       'count_proteins_reason': 'negative_points_less_than_11',
#       'is_beverage': 0,
#       'is_cheese': 0,
#       'is_fat_oil_nuts_seeds': 0,
#       'is_red_meat_product': 0,
#       'is_water': 0,
#       'negative_points': 6,
#       'negative_points_max': 55,
#       'positive_nutrients': ['proteins', 'fiber', 'fruits_vegetables_legumes'],
#       'positive_points': 2,
#       'positive_points_max': 17},
#      'grade': 'c',
#      'nutrients_available': 1,
#      'nutriscore_applicable': 1,
#      'nutriscore_computed': 1,
#      'score': 4}},
#    'nutriscore_2021_tags': ['b'],
#    'nutriscore_2023_tags': ['c'],
#    'nutriscore_data': {'components': {'negative': [{'id': 'energy',
#        'points': 1,
#        'points_max': 10,
#        'unit': 'kJ',
#        'value': 661},
#       {'id': 'sugars',
#        'points': 1,
#        'points_max': 15,
#        'unit': 'g',
#        'value': 5.4},
#       {'id': 'saturated_fat',
#        'points': 0,
#        'points_max': 10,
#        'unit': 'g',
#        'value': 1},
#       {'id': 'salt',
#        'points': 4,
#        'points_max': 20,
#        'unit': 'g',
#        'value': 0.88}],
#      'positive': [{'id': 'proteins',
#        'points': 2,
#        'points_max': 7,
#        'unit': 'g',
#        'value': 5.4},
#       {'id': 'fiber', 'points': 0, 'points_max': 5, 'unit': 'g', 'value': 0.7},
#       {'id': 'fruits_vegetables_legumes',
#        'points': 0,
#        'points_max': 5,
#        'unit': '%',
#        'value': 20.6}]},
#     'count_proteins': 1,
#     'count_proteins_reason': 'negative_points_less_than_11',
#     'grade': 'c',
#     'is_beverage': 0,
#     'is_cheese': 0,
#     'is_fat_oil_nuts_seeds': 0,
#     'is_red_meat_product': 0,
#     'is_water': 0,
#     'negative_points': 6,
#     'negative_points_max': 55,
#     'positive_nutrients': ['proteins', 'fiber', 'fruits_vegetables_legumes'],
#     'positive_points': 2,
#     'positive_points_max': 17,
#     'score': 4},
#    'nutriscore_grade': 'c',
#    'nutriscore_score': 4,
#    'nutriscore_score_opposite': -4,
#    'nutriscore_tags': ['c'],
#    'nutriscore_version': '2023',
#    'nutrition_data': 'on',
#    'nutrition_data_per': '100g',
#    'nutrition_data_prepared_per': '100g',
#    'nutrition_grade_fr': 'c',
#    'nutrition_grades': 'c',
#    'nutrition_grades_tags': ['c'],
#    'nutrition_score_beverage': 0,
#    'nutrition_score_debug': '',
#    'nutrition_score_warning_fruits_vegetables_legumes_estimate_from_ingredients': 1,
#    'nutrition_score_warning_fruits_vegetables_legumes_estimate_from_ingredients_value': 20.5528390066964,
#    'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#    'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 20.9903390066964,
#    'other_nutritional_substances_tags': [],
#    'packaging': 'en:card-sleeve, en:pp-tub, en:ldpe-film',
#    'packaging_hierarchy': ['en:card-sleeve', 'en:ldpe-film', 'en:pp-tub'],
#    'packaging_lc': 'en',
#    'packaging_materials_tags': [],
#    'packaging_recycling_tags': [],
#    'packaging_shapes_tags': ['en:pot'],
#    'packaging_tags': ['en:card-sleeve', 'en:ldpe-film', 'en:pp-tub'],
#    'packagings': [{'shape': 'en:pot'}],
#    'packagings_materials': {'all': {}, 'en:unknown': {}},
#    'packagings_n': 1,
#    'photographers_tags': ['smoothie-app',
#     'rachipetal',
#     'macrofactor',
#     'foodvisor'],
#    'pnns_groups_1': 'Composite foods',
#    'pnns_groups_1_tags': ['composite-foods', 'known'],
#    'pnns_groups_2': 'One-dish meals',
#    'pnns_groups_2_tags': ['one-dish-meals', 'known'],
#    'popularity_key': 23995000081,
#    'popularity_tags': ['top-50000-scans-2023',
#     'top-100000-scans-2023',
#     'at-least-5-scans-2023',
#     'at-least-10-scans-2023',
#     'top-75-percent-scans-2023',
#     'top-80-percent-scans-2023',
#     'top-85-percent-scans-2023',
#     'top-90-percent-scans-2023',
#     'top-5000-gb-scans-2023',
#     'top-10000-gb-scans-2023',
#     'top-50000-gb-scans-2023',
#     'top-100000-gb-scans-2023',
#     'top-country-gb-scans-2023',
#     'at-least-5-gb-scans-2023',
#     'at-least-10-gb-scans-2023',
#     'top-5000-hr-scans-2023',
#     'top-10000-hr-scans-2023',
#     'top-50000-hr-scans-2023',
#     'top-100000-hr-scans-2023',
#     'top-5000-scans-2024',
#     'top-10000-scans-2024',
#     'top-50000-scans-2024',
#     'top-100000-scans-2024',
#     'at-least-5-scans-2024',
#     'at-least-10-scans-2024',
#     'top-75-percent-scans-2024',
#     'top-80-percent-scans-2024',
#     'top-85-percent-scans-2024',
#     'top-90-percent-scans-2024',
#     'top-5000-gb-scans-2024',
#     'top-10000-gb-scans-2024',
#     'top-50000-gb-scans-2024',
#     'top-100000-gb-scans-2024',
#     'top-country-gb-scans-2024',
#     'at-least-5-gb-scans-2024',
#     'at-least-10-gb-scans-2024',
#     'top-500-im-scans-2024',
#     'top-1000-im-scans-2024',
#     'top-5000-im-scans-2024',
#     'top-10000-im-scans-2024',
#     'top-50000-im-scans-2024',
#     'top-100000-im-scans-2024'],
#    'product_name': 'Rainbow Salmon Poke',
#    'product_name_en': 'Rainbow Salmon Poke',
#    'product_quantity': '283',
#    'product_quantity_unit': 'g',
#    'product_type': 'food',
#    'quantity': '283g',
#    'removed_countries_tags': [],
#    'rev': 28,
#    'scans_n': 71,
#    'schema_version': 996,
#    'selected_images': {'front': {'display': {'en': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.400.jpg'},
#      'small': {'en': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.200.jpg'},
#      'thumb': {'en': 'https://images.openfoodfacts.org/images/products/503/527/293/7469/front_en.19.100.jpg'}}},
#    'serving_quantity': '283',
#    'serving_quantity_unit': 'g',
#    'serving_size': '1 bowl (283 g)',
#    'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-to-be-completed, en:packaging-code-to-be-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-validated, en:packaging-photo-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#    'states_hierarchy': ['en:to-be-completed',
#     'en:nutrition-facts-completed',
#     'en:ingredients-completed',
#     'en:expiration-date-to-be-completed',
#     'en:packaging-code-to-be-completed',
#     'en:characteristics-to-be-completed',
#     'en:origins-to-be-completed',
#     'en:categories-completed',
#     'en:brands-completed',
#     'en:packaging-completed',
#     'en:quantity-completed',
#     'en:product-name-completed',
#     'en:photos-validated',
#     'en:packaging-photo-selected',
#     'en:nutrition-photo-selected',
#     'en:ingredients-photo-selected',
#     'en:front-photo-selected',
#     'en:photos-uploaded'],
#    'states_tags': ['en:to-be-completed',
#     'en:nutrition-facts-completed',
#     'en:ingredients-completed',
#     'en:expiration-date-to-be-completed',
#     'en:packaging-code-to-be-completed',
#     'en:characteristics-to-be-completed',
#     'en:origins-to-be-completed',
#     'en:categories-completed',
#     'en:brands-completed',
#     'en:packaging-completed',
#     'en:quantity-completed',
#     'en:product-name-completed',
#     'en:photos-validated',
#     'en:packaging-photo-selected',
#     'en:nutrition-photo-selected',
#     'en:ingredients-photo-selected',
#     'en:front-photo-selected',
#     'en:photos-uploaded'],
#    'traces': '',
#    'traces_from_ingredients': '',
#    'traces_from_user': '(en) ',
#    'traces_hierarchy': [],
#    'traces_tags': [],
#    'unique_scans_n': 69,
#    'unknown_ingredients_n': 2,
#    'unknown_nutrients_tags': [],
#    'update_key': 'sort',
#    'url': 'https://world.openfoodfacts.org/product/5035272937469/rainbow-salmon-poke-yo',
#    'vitamins_tags': [],
#    'weighers_tags': []},
#   {'_id': '20177089',
#    '_keywords': ['ahumado',
#     'alemania',
#     'and',
#     'de',
#     'en',
#     'fishe',
#     'loncha',
#     'noruega',
#     'ocean',
#     'product',
#     'salmon',
#     'sea',
#     'seafood',
#     'smoked',
#     'their'],
#    'added_countries_tags': [],
#    'additives_n': 1,
#    'additives_original_tags': ['en:e325'],
#    'additives_tags': ['en:e325'],
#    'allergens': 'en:fish',
#    'allergens_from_ingredients': 'en:fish',
#    'allergens_from_user': '(es) en:fish',
#    'allergens_hierarchy': ['en:fish'],
#    'allergens_tags': ['en:fish'],
#    'amino_acids_prev_tags': [],
#    'amino_acids_tags': [],
#    'brands': 'Ocean Sea',
#    'brands_old': 'Ocean Sea',
#    'brands_tags': ['ocean-sea'],
#    'categories': 'Seafood,Fishes and their products,Fishes,Salmons,Smoked fishes,Smoked salmons',
#    'categories_hierarchy': ['en:seafood',
#     'en:fishes-and-their-products',
#     'en:fishes',
#     'en:fatty-fishes',
#     'en:salmons',
#     'en:smoked-fishes',
#     'en:smoked-salmons'],
#    'categories_lc': 'en',
#    'categories_old': 'en:Seafood,en:Fishes and their products,Pești,en:Fatty fishes,en:Salmons,en:Smoked fishes,Somon afumat,Smoked salmons',
#    'categories_properties': {'agribalyse_food_code:en': '26037',
#     'agribalyse_proxy_food_code:en': '26036',
#     'ciqual_food_code:en': '26037'},
#    'categories_properties_tags': ['all-products',
#     'categories-known',
#     'agribalyse-food-code-26037',
#     'agribalyse-food-code-known',
#     'agribalyse-proxy-food-code-26036',
#     'agribalyse-proxy-food-code-known',
#     'ciqual-food-code-26037',
#     'ciqual-food-code-known',
#     'agribalyse-known',
#     'agribalyse-26037'],
#    'categories_tags': ['en:seafood',
#     'en:fishes-and-their-products',
#     'en:fishes',
#     'en:fatty-fishes',
#     'en:salmons',
#     'en:smoked-fishes',
#     'en:smoked-salmons'],
#    'category_properties': {'ciqual_food_name:en': 'Salmon, smoked'},
#    'checkers_tags': [],
#    'ciqual_food_name_tags': ['salmon-smoked'],
#    'cities_tags': [],
#    'code': '20177089',
#    'codes_tags': ['code-8',
#     '20177xxx',
#     '2017xxxx',
#     '201xxxxx',
#     '20xxxxxx',
#     '2xxxxxxx'],
#    'compared_to_category': 'en:smoked-salmons',
#    'complete': 0,
#    'completeness': 0.975,
#    'correctors_tags': ['packbot',
#     'openfoodfacts-contributors',
#     'anonymous-2hsi6zk3oq',
#     'rayssavidal',
#     'feat',
#     'caraldine',
#     'fromagestelaire',
#     'offy24',
#     'macrofactor'],
#    'countries': 'Francia,Irlanda,Italia,España',
#    'countries_hierarchy': ['en:france', 'en:ireland', 'en:italy', 'en:spain'],
#    'countries_lc': 'es',
#    'countries_tags': ['en:france', 'en:ireland', 'en:italy', 'en:spain'],
#    'created_t': 1544172587,
#    'creator': 'date-limite-app',
#    'data_quality_bugs_tags': [],
#    'data_quality_errors_tags': [],
#    'data_quality_info_tags': ['en:packaging-data-incomplete',
#     'en:ingredients-percent-analysis-ok',
#     'en:sum-of-ingredients-with-unspecified-percent-lesser-than-10',
#     'en:environmental-score-extended-data-not-computed',
#     'en:food-groups-1-known',
#     'en:food-groups-2-known',
#     'en:food-groups-3-known'],
#    'data_quality_tags': ['en:packaging-data-incomplete',
#     'en:ingredients-percent-analysis-ok',
#     'en:sum-of-ingredients-with-unspecified-percent-lesser-than-10',
#     'en:environmental-score-extended-data-not-computed',
#     'en:food-groups-1-known',
#     'en:food-groups-2-known',
#     'en:food-groups-3-known',
# ...
#    'last_edit_dates_tags': ['2025-02-04', '2025-02', '2025'],
#    'last_editor': 'scanbot',
#    'last_image_dates_tags': ['2019-12-10', '2019-12', '2019'],
#    'last_image_t': 1575999430,
#    'last_modified_by': 'scanbot',
#    'last_modified_t': 1738675709,
#    'last_updated_t': 1743697348,
#    'lc': 'es',
#    'link': '',
#    'main_countries_tags': [],
#    'manufacturing_places': 'España',
#    'manufacturing_places_tags': ['espana'],
#    'max_imgid': '9',
#    'minerals_prev_tags': [],
#    'minerals_tags': [],
#    'misc_tags': ['en:environmental-score-not-computed',
#     'en:nutriscore-2021-d-2023-d',
#     'en:nutriscore-2021-same-as-2023',
#     'en:nutriscore-computed',
#     'en:nutrition-fruits-vegetables-legumes-estimate-from-ingredients',
#     'en:nutrition-fruits-vegetables-nuts-estimate-from-ingredients',
#     'en:nutrition-no-fiber',
#     'en:nutrition-no-fiber-or-fruits-vegetables-nuts',
#     'en:packagings-not-complete',
#     'en:packagings-not-empty',
#     'en:packagings-not-empty-but-not-complete',
#     'en:packagings-number-of-components-1',
#     'en:some-ingredients-with-specified-percent'],
#    'no_nutrition_data': '',
#    'nova_group': 4,
#    'nova_group_debug': '',
#    'nova_groups': '4',
#    'nova_groups_markers': {'3': [['categories', 'en:prepared-meats'],
#      ['ingredients', 'en:salt'],
#      ['ingredients', 'en:vegetable-oil']],
#     '4': [['additives', 'en:e160c'],
#      ['ingredients', 'en:colour'],
#      ['ingredients', 'en:flavouring']]},
#    'nova_groups_tags': ['en:4-ultra-processed-food-and-drink-products'],
#    'nucleotides_prev_tags': [],
#    'nucleotides_tags': [],
#    'nutrient_levels': {'fat': 'high',
#     'salt': 'high',
#     'saturated-fat': 'moderate',
#     'sugars': 'low'},
#    'nutrient_levels_tags': ['en:fat-in-high-quantity',
#     'en:saturated-fat-in-moderate-quantity',
#     'en:sugars-in-low-quantity',
#     'en:salt-in-high-quantity'],
#    'nutriments': {'carbohydrates': 1.7,
#     'carbohydrates_100g': 1.7,
#     'carbohydrates_unit': 'g',
#     'carbohydrates_value': 1.7,
#     'carbon-footprint-from-known-ingredients_product': 422,
#     'energy': 1155,
#     'energy-kcal': 280,
#     'energy-kcal_100g': 280,
#     'energy-kcal_unit': 'kcal',
#     'energy-kcal_value': 280,
#     'energy-kcal_value_computed': 279.6,
#     'energy-kj': 1155,
#     'energy-kj_100g': 1155,
#     'energy-kj_unit': 'kJ',
#     'energy-kj_value': 1155,
#     'energy-kj_value_computed': 1154.8,
#     'energy_100g': 1155,
#     'energy_unit': 'kJ',
#     'energy_value': 1155,
#     'fat': 26.8,
#     'fat_100g': 26.8,
#     'fat_unit': 'g',
#     'fat_value': 26.8,
#     'fruits-vegetables-legumes-estimate-from-ingredients_100g': 0,
#     'fruits-vegetables-legumes-estimate-from-ingredients_serving': 0,
#     'fruits-vegetables-nuts-estimate-from-ingredients_100g': 0,
#     'fruits-vegetables-nuts-estimate-from-ingredients_serving': 0,
#     'nova-group': 4,
#     'nova-group_100g': 4,
#     'nova-group_serving': 4,
#     'nutrition-score-fr': 15,
#     'nutrition-score-fr_100g': 15,
#     'proteins': 7.9,
#     'proteins_100g': 7.9,
#     'proteins_unit': 'g',
#     'proteins_value': 7.9,
#     'salt': 2,
#     'salt_100g': 2,
#     'salt_unit': 'g',
#     'salt_value': 2,
#     'saturated-fat': 3.4,
#     'saturated-fat_100g': 3.4,
#     'saturated-fat_unit': 'g',
#     'saturated-fat_value': 3.4,
#     'sodium': 0.8,
#     'sodium_100g': 0.8,
#     'sodium_unit': 'g',
#     'sodium_value': 0.8,
#     'sugars': 1.7,
#     'sugars_100g': 1.7,
#     'sugars_unit': 'g',
#     'sugars_value': 1.7},
#    'nutriscore': {'2021': {'category_available': 1,
#      'data': {'energy': 1155,
#       'energy_points': 3,
#       'energy_value': 1155,
#       'fiber': 0,
#       'fiber_points': 0,
#       'fiber_value': 0.0,
#       'fruits_vegetables_nuts_colza_walnut_olive_oils': 0,
#       'fruits_vegetables_nuts_colza_walnut_olive_oils_points': 0,
#       'fruits_vegetables_nuts_colza_walnut_olive_oils_value': 0,
#       'is_beverage': 0,
#       'is_cheese': 0,
#       'is_fat': 0,
#       'is_water': 0,
#       'negative_points': 14,
#       'positive_points': 0,
#       'proteins': 7.9,
#       'proteins_points': 4,
#       'proteins_value': 7.9,
#       'saturated_fat': 3.4,
#       'saturated_fat_points': 3,
#       'saturated_fat_value': 3.4,
#       'sodium': 800.0,
#       'sodium_points': 8,
#       'sodium_value': 800,
#       'sugars': 1.7,
#       'sugars_points': 0,
#       'sugars_value': 1.7},
#      'grade': 'd',
#      'nutrients_available': 1,
#      'nutriscore_applicable': 1,
#      'nutriscore_computed': 1,
#      'score': 14},
#     '2023': {'category_available': 1,
#      'data': {'components': {'negative': [{'id': 'energy',
#          'points': 3,
#          'points_max': 10,
#          'unit': 'kJ',
#          'value': 1155},
#         {'id': 'sugars',
#          'points': 0,
#          'points_max': 15,
#          'unit': 'g',
#          'value': 1.7},
#         {'id': 'saturated_fat',
#          'points': 3,
#          'points_max': 10,
#          'unit': 'g',
#          'value': 3.4},
#         {'id': 'salt',
#          'points': 9,
#          'points_max': 20,
#          'unit': 'g',
#          'value': 2}],
#        'positive': [{'id': 'fiber',
#          'points': 0,
#          'points_max': 5,
#          'unit': 'g',
#          'value': None},
#         {'id': 'fruits_vegetables_legumes',
#          'points': 0,
#          'points_max': 5,
#          'unit': '%',
#          'value': 0}]},
#       'count_proteins': 0,
#       'count_proteins_reason': 'negative_points_greater_than_or_equal_to_11',
#       'is_beverage': 0,
#       'is_cheese': 0,
#       'is_fat_oil_nuts_seeds': 0,
#       'is_red_meat_product': 0,
#       'is_water': 0,
#       'negative_points': 15,
#       'negative_points_max': 55,
#       'positive_nutrients': ['fiber', 'fruits_vegetables_legumes'],
#       'positive_points': 0,
#       'positive_points_max': 10},
#      'grade': 'd',
#      'nutrients_available': 1,
#      'nutriscore_applicable': 1,
#      'nutriscore_computed': 1,
#      'score': 15}},
#    'nutriscore_2021_tags': ['d'],
#    'nutriscore_2023_tags': ['d'],
#    'nutriscore_data': {'components': {'negative': [{'id': 'energy',
#        'points': 3,
#        'points_max': 10,
#        'unit': 'kJ',
#        'value': 1155},
#       {'id': 'sugars',
#        'points': 0,
#        'points_max': 15,
#        'unit': 'g',
#        'value': 1.7},
#       {'id': 'saturated_fat',
#        'points': 3,
#        'points_max': 10,
#        'unit': 'g',
#        'value': 3.4},
#       {'id': 'salt', 'points': 9, 'points_max': 20, 'unit': 'g', 'value': 2}],
#      'positive': [{'id': 'fiber',
#        'points': 0,
#        'points_max': 5,
#        'unit': 'g',
#        'value': None},
#       {'id': 'fruits_vegetables_legumes',
#        'points': 0,
#        'points_max': 5,
#        'unit': '%',
#        'value': 0}]},
#     'count_proteins': 0,
#     'count_proteins_reason': 'negative_points_greater_than_or_equal_to_11',
#     'grade': 'd',
#     'is_beverage': 0,
#     'is_cheese': 0,
#     'is_fat_oil_nuts_seeds': 0,
#     'is_red_meat_product': 0,
#     'is_water': 0,
#     'negative_points': 15,
#     'negative_points_max': 55,
#     'positive_nutrients': ['fiber', 'fruits_vegetables_legumes'],
#     'positive_points': 0,
#     'positive_points_max': 10,
#     'score': 15},
#    'nutriscore_grade': 'd',
#    'nutriscore_score': 15,
#    'nutriscore_score_opposite': -15,
#    'nutriscore_tags': ['d'],
#    'nutriscore_version': '2023',
#    'nutrition_data': 'on',
#    'nutrition_data_per': '100g',
#    'nutrition_data_prepared': '',
#    'nutrition_data_prepared_per': '100g',
#    'nutrition_grade_fr': 'd',
#    'nutrition_grades': 'd',
#    'nutrition_grades_tags': ['d'],
#    'nutrition_score_beverage': 0,
#    'nutrition_score_debug': '',
#    'nutrition_score_warning_fruits_vegetables_legumes_estimate_from_ingredients': 1,
#    'nutrition_score_warning_fruits_vegetables_legumes_estimate_from_ingredients_value': 0,
#    'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients': 1,
#    'nutrition_score_warning_fruits_vegetables_nuts_estimate_from_ingredients_value': 0,
#    'nutrition_score_warning_no_fiber': 1,
#    'obsolete': '',
#    'obsolete_since_date': '',
#    'origins': '',
#    'origins_hierarchy': [],
#    'origins_lc': 'es',
#    'origins_old': '',
#    'origins_tags': [],
#    'other_nutritional_substances_tags': [],
#    'packaging': 'Tarro vidrio',
#    'packaging_hierarchy': ['es:Tarro vidrio'],
#    'packaging_lc': 'es',
#    'packaging_materials_tags': ['en:glass'],
#    'packaging_old': 'Tarro vidrio',
#    'packaging_old_before_taxonomization': 'tarro vidrio',
#    'packaging_recycling_tags': [],
#    'packaging_shapes_tags': ['en:jar'],
#    'packaging_tags': ['es:tarro-vidrio'],
#    'packagings': [{'food_contact': 1,
#      'material': 'en:glass',
#      'shape': 'en:jar'}],
#    'packagings_materials': {'all': {}, 'en:glass': {}},
#    'packagings_n': 1,
#    'photographers_tags': ['kiliweb', 'osimo'],
#    'pnns_groups_1': 'Cereals and potatoes',
#    'pnns_groups_1_tags': ['cereals-and-potatoes', 'known'],
#    'pnns_groups_2': 'Cereals',
#    'pnns_groups_2_tags': ['cereals', 'known'],
#    'popularity_key': 23950000027,
#    'popularity_tags': ['top-50000-scans-2019',
#     'top-100000-scans-2019',
#     'at-least-5-scans-2019',
#     'at-least-10-scans-2019',
#     'top-75-percent-scans-2019',
#     'top-80-percent-scans-2019',
#     'top-85-percent-scans-2019',
#     'top-90-percent-scans-2019',
#     'top-5000-es-scans-2019',
#     'top-10000-es-scans-2019',
#     'top-50000-es-scans-2019',
#     'top-100000-es-scans-2019',
#     'top-country-es-scans-2019',
#     'at-least-5-es-scans-2019',
#     'at-least-10-es-scans-2019',
#     'top-50000-scans-2020',
#     'top-100000-scans-2020',
#     'at-least-5-scans-2020',
#     'at-least-10-scans-2020',
#     'top-75-percent-scans-2020',
#     'top-80-percent-scans-2020',
#     'top-85-percent-scans-2020',
#     'top-90-percent-scans-2020',
#     'top-5000-es-scans-2020',
#     'top-10000-es-scans-2020',
#     'top-50000-es-scans-2020',
#     'top-100000-es-scans-2020',
#     'top-country-es-scans-2020',
#     'at-least-5-es-scans-2020',
#     'at-least-10-es-scans-2020',
#     'top-1000-ar-scans-2020',
#     'top-5000-ar-scans-2020',
#     'top-10000-ar-scans-2020',
#     'top-50000-ar-scans-2020',
#     'top-100000-ar-scans-2020',
#     'top-50000-de-scans-2020',
#     'top-100000-de-scans-2020',
#     'top-500-al-scans-2020',
#     'top-1000-al-scans-2020',
#     'top-5000-al-scans-2020',
#     'top-10000-al-scans-2020',
#     'top-50000-al-scans-2020',
#     'top-100000-al-scans-2020',
#     'top-50000-scans-2021',
#     'top-100000-scans-2021',
#     'at-least-5-scans-2021',
#     'at-least-10-scans-2021',
#     'top-75-percent-scans-2021',
#     'top-80-percent-scans-2021',
#     'top-85-percent-scans-2021',
#     'top-90-percent-scans-2021',
#     'top-5000-es-scans-2021',
#     'top-10000-es-scans-2021',
#     'top-50000-es-scans-2021',
#     'top-100000-es-scans-2021',
#     'top-country-es-scans-2021',
#     'at-least-5-es-scans-2021',
#     'at-least-10-es-scans-2021',
#     'top-50000-us-scans-2021',
#     'top-100000-us-scans-2021',
#     'top-10000-ma-scans-2021',
#     'top-50000-ma-scans-2021',
#     'top-100000-ma-scans-2021',
#     'top-50000-scans-2022',
#     'top-100000-scans-2022',
#     'at-least-5-scans-2022',
#     'at-least-10-scans-2022',
#     'top-75-percent-scans-2022',
#     'top-80-percent-scans-2022',
#     'top-85-percent-scans-2022',
#     'top-90-percent-scans-2022',
#     'top-5000-es-scans-2022',
#     'top-10000-es-scans-2022',
#     'top-50000-es-scans-2022',
#     'top-100000-es-scans-2022',
#     'top-country-es-scans-2022',
#     'at-least-5-es-scans-2022',
#     'at-least-10-es-scans-2022',
#     'top-5000-ma-scans-2022',
#     'top-10000-ma-scans-2022',
#     'top-50000-ma-scans-2022',
#     'top-100000-ma-scans-2022',
#     'top-50000-scans-2023',
#     'top-100000-scans-2023',
#     'at-least-5-scans-2023',
#     'at-least-10-scans-2023',
#     'top-75-percent-scans-2023',
#     'top-80-percent-scans-2023',
#     'top-85-percent-scans-2023',
#     'top-90-percent-scans-2023',
#     'top-5000-es-scans-2023',
#     'top-10000-es-scans-2023',
#     'top-50000-es-scans-2023',
#     'top-100000-es-scans-2023',
#     'top-country-es-scans-2023',
#     'at-least-5-es-scans-2023',
#     'at-least-10-es-scans-2023',
#     'top-5000-ma-scans-2023',
#     'top-10000-ma-scans-2023',
#     'top-50000-ma-scans-2023',
#     'top-100000-ma-scans-2023',
#     'top-50000-gb-scans-2023',
#     'top-100000-gb-scans-2023',
#     'top-50000-scans-2024',
#     'top-100000-scans-2024',
#     'at-least-5-scans-2024',
#     'at-least-10-scans-2024',
#     'top-75-percent-scans-2024',
#     'top-80-percent-scans-2024',
#     'top-85-percent-scans-2024',
#     'top-90-percent-scans-2024',
#     'top-5000-es-scans-2024',
#     'top-10000-es-scans-2024',
#     'top-50000-es-scans-2024',
#     'top-100000-es-scans-2024',
#     'top-country-es-scans-2024',
#     'at-least-5-es-scans-2024',
#     'at-least-10-es-scans-2024',
#     'top-10000-ma-scans-2024',
#     'top-50000-ma-scans-2024',
#     'top-100000-ma-scans-2024',
#     'at-least-5-ma-scans-2024',
#     'top-10000-nl-scans-2024',
#     'top-50000-nl-scans-2024',
#     'top-100000-nl-scans-2024',
#     'top-10000-dz-scans-2024',
#     'top-50000-dz-scans-2024',
#     'top-100000-dz-scans-2024'],
#    'product_name': 'Paté de salmón',
#    'product_name_es': 'Paté de salmón',
#    'product_name_fr': '',
#    'product_quantity': 160,
#    'product_quantity_unit': 'g',
#    'product_type': 'food',
#    'purchase_places': 'España',
#    'purchase_places_tags': ['espana'],
#    'quantity': '160 g',
#    'removed_countries_tags': [],
#    'rev': 42,
#    'scans_n': 27,
#    'schema_version': 996,
#    'selected_images': {'front': {'display': {'es': 'https://images.openfoodfacts.org/images/products/848/000/052/3365/front_es.23.400.jpg'},
#      'small': {'es': 'https://images.openfoodfacts.org/images/products/848/000/052/3365/front_es.23.200.jpg'},
#      'thumb': {'es': 'https://images.openfoodfacts.org/images/products/848/000/052/3365/front_es.23.100.jpg'}}},
#    'sortkey': 1589297751,
#    'states': 'en:to-be-completed, en:nutrition-facts-completed, en:ingredients-completed, en:expiration-date-to-be-completed, en:packaging-code-completed, en:characteristics-to-be-completed, en:origins-to-be-completed, en:categories-completed, en:brands-completed, en:packaging-completed, en:quantity-completed, en:product-name-completed, en:photos-to-be-validated, en:packaging-photo-to-be-selected, en:nutrition-photo-selected, en:ingredients-photo-selected, en:front-photo-selected, en:photos-uploaded',
#    'states_hierarchy': ['en:to-be-completed',
#     'en:nutrition-facts-completed',
#     'en:ingredients-completed',
#     'en:expiration-date-to-be-completed',
#     'en:packaging-code-completed',
#     'en:characteristics-to-be-completed',
#     'en:origins-to-be-completed',
#     'en:categories-completed',
#     'en:brands-completed',
#     'en:packaging-completed',
#     'en:quantity-completed',
#     'en:product-name-completed',
#     'en:photos-to-be-validated',
#     'en:packaging-photo-to-be-selected',
#     'en:nutrition-photo-selected',
#     'en:ingredients-photo-selected',
#     'en:front-photo-selected',
#     'en:photos-uploaded'],
#    'states_tags': ['en:to-be-completed',
#     'en:nutrition-facts-completed',
#     'en:ingredients-completed',
#     'en:expiration-date-to-be-completed',
#     'en:packaging-code-completed',
#     'en:characteristics-to-be-completed',
#     'en:origins-to-be-completed',
#     'en:categories-completed',
#     'en:brands-completed',
#     'en:packaging-completed',
#     'en:quantity-completed',
#     'en:product-name-completed',
#     'en:photos-to-be-validated',
#     'en:packaging-photo-to-be-selected',
#     'en:nutrition-photo-selected',
#     'en:ingredients-photo-selected',
#     'en:front-photo-selected',
#     'en:photos-uploaded'],
#    'stores': 'Mercadona',
#    'stores_tags': ['mercadona'],
#    'traces': 'en:fish,en:milk',
#    'traces_from_ingredients': '',
#    'traces_from_user': '(fr) en:fish,en:milk',
#    'traces_hierarchy': ['en:fish', 'en:milk'],
#    'traces_lc': 'fr',
#    'traces_tags': ['en:fish', 'en:milk'],
#    'unique_scans_n': 27,
#    'unknown_ingredients_n': 0.0,
#    'unknown_nutrients_tags': [],
#    'update_key': 'brands',
#    'url': 'https://world.openfoodfacts.org/product/8480000523365/pate-de-salmon-hacendado',
#    'vitamins_prev_tags': [],
#    'vitamins_tags': [],
#    'weighers_tags': []}],
#  'skip': 0}
